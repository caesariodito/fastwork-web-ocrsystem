# %%
import pandas as pd

# %%
df = pd.read_csv('./data/data_gambar_pln.csv', header=None, names=['link'])
df
# Out:
#                                                   link
# 0    https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 1    https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 2    https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 3    https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 4    https://portalapp.iconpln.co.id/acmt/DisplayBl...
# ..                                                 ...
# 392  https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 393  https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 394  https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 395  https://portalapp.iconpln.co.id/acmt/DisplayBl...
# 396  https://portalapp.iconpln.co.id/acmt/DisplayBl...
#
# [397 rows x 1 columns]

# %%
import urllib.request

errors = []
for i in range(81,len(df)):
    try:
        urllib.request.urlretrieve(df['link'][i], f'./data/images/gambar_pln_{i}.jpg')
        print(f'gambar_pln_{i}.jpg downloaded')
    except Exception as e:
        print(f'gambar_pln_{i}.jpg failed to download')
        print(e)
        errors.append(df['link'][i])
# Out:
# gambar_pln_81.jpg downloaded
# gambar_pln_82.jpg downloaded
# gambar_pln_83.jpg downloaded
# gambar_pln_84.jpg downloaded
# gambar_pln_85.jpg downloaded
# gambar_pln_86.jpg downloaded
# gambar_pln_87.jpg downloaded
# gambar_pln_88.jpg downloaded
# gambar_pln_89.jpg downloaded
# gambar_pln_90.jpg downloaded
# gambar_pln_91.jpg downloaded
# gambar_pln_92.jpg downloaded
# gambar_pln_93.jpg downloaded
# gambar_pln_94.jpg downloaded
# gambar_pln_95.jpg downloaded
# gambar_pln_96.jpg downloaded
# gambar_pln_97.jpg downloaded
# gambar_pln_98.jpg downloaded
# gambar_pln_99.jpg downloaded
# gambar_pln_100.jpg downloaded
# gambar_pln_101.jpg downloaded
# gambar_pln_102.jpg downloaded
# gambar_pln_103.jpg downloaded
# gambar_pln_104.jpg downloaded
# gambar_pln_105.jpg downloaded
# gambar_pln_106.jpg downloaded
# gambar_pln_107.jpg downloaded
# gambar_pln_108.jpg downloaded
# gambar_pln_109.jpg downloaded
# gambar_pln_110.jpg downloaded
# gambar_pln_111.jpg downloaded
# ...
